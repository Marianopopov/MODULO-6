# %%
import pandas as pd

# %%
df = pd.read_csv('Hospitalización.csv', encoding= 'latin-1')

# %%
df
# Out:
#      Edad Diabetes Hospitalizacion_Ultimo_Mes   PSA Biopsias_Previas  \
# 0    53.0       NO                         NO     4               NO
# 1    56.0       NO                         NO   7,7               NO
# 2    57.0       NO                         NO    29               SI
# 3    56.0       NO                         NO     7               NO
# 4    55.0       NO                         NO    29               SI
# ..    ...      ...                        ...   ...              ...
# 565  69.0       NO                         NO  4,43              NaN
# 566  67.0       NO                         NO     8               NO
# 567  59.0       NO                         NO     9               SI
# 568   NaN      NaN                        NaN   NaN              NaN
# 569   NaN      NaN                        NaN   NaN              NaN
#
#     Volumen_Prostatico          Antibiotico_Profilaxis  \
# 0                   SI  FLUOROQUINOLONA_AMINOGLICOSIDO
# 1                   SI  FLUOROQUINOLONA_AMINOGLICOSIDO
# 2                   SI  FLUOROQUINOLONA_AMINOGLICOSIDO
# 3                   SI  FLUOROQUINOLONA_AMINOGLICOSIDO
# 4                   SI  FLUOROQUINOLONA_AMINOGLICOSIDO
# ..                 ...                             ...
# 565                NaN  FLUOROQUINOLONA_AMINOGLICOSIDO
# 566                 SI  FLUOROQUINOLONA_AMINOGLICOSIDO
# 567                 SI  FLUOROQUINOLONA_AMINOGLICOSIDO
# 568                NaN                             NaN
# 569                NaN                             NaN
#
#      Numero_Muestras_Tomadas       CUP Enf_Cronica_Pulmonar_Obstructiva  \
# 0                       12.0        NO                               NO
# 1                       12.0        NO                               NO
# 2                       24.0        NO                               NO
# 3                       12.0        NO                               NO
# 4                       24.0        NO                               NO
# ..                       ...       ...                              ...
# 565                     20.0       NaN                               NO
# 566                     12.0        NO                              NaN
# 567                     12.0        NO                              NaN
# 568                      NaN       NaN                              NaN
# 569                      NaN  #¡VALOR!                              NaN
#
#                        Biopsia Dias_Post_Biopsia_Complicacion Fiebre  ITU  \
# 0                          NEG                              1     SI   NO
# 1                          NEG                              1     SI   NO
# 2                          NEG                              1     SI   NO
# 3                          NEG                              1     SI   NO
# 4                          NEG                              1     SI   NO
# ..                         ...                            ...    ...  ...
# 565                        NEG                             NO     NO   NO
# 566  ADENOCARCINOMA GLEASON 7                              NO     NO   NO
# 567                        NEG                             NO     NO   NO
# 568                        NaN                            NaN    NaN  NaN
# 569                        NaN                            NaN    NaN  NaN
#
#     Tipo_Cultivo Agente_Aislado                    Patron_Resistencia  \
# 0             NO             NO                                    NO
# 1             NO             NO                                    NO
# 2    HEMOCULTIVO         E.COLI   AMPI R, CIPRO R, GENTA R, SULFA M R
# 3             NO             NO                                    NO
# 4    HEMOCULTIVO         E.COLI                                    NO
# ..           ...            ...                                   ...
# 565           NO             NO                                    NO
# 566           NO            NaN                                    NO
# 567           NO             NO                                    NO
# 568          NaN            NaN                                   NaN
# 569          NaN            NaN                                   NaN
#
#     Hospitalizacion  Dias_Hospitalizacion_MQ  Dias_Hospitalizacion_UPC
# 0                SI                      2.0                       0.0
# 1                SI                      5.0                       0.0
# 2                SI                      4.0                       3.0
# 3                SI                      5.0                       0.0
# 4                SI                      4.0                       3.0
# ..              ...                      ...                       ...
# 565              NO                      0.0                       0.0
# 566              NO                      0.0                       0.0
# 567              NO                      0.0                       0.0
# 568             NaN                      NaN                       NaN
# 569             NaN                      NaN                       NaN
#
# [570 rows x 20 columns]

# %%
nuevos_nombres = {
    'EDAD': 'Edad',
    'DIABETES': 'Diabetes',
    'HOSPITALIZACIÓN ULTIMO MES': 'Hospitalizacion_Ultimo_Mes',
    'PSA': 'PSA',
    'BIOPSIAS PREVIAS': 'Biopsias_Previas',
    'VOLUMEN PROSTATICO': 'Volumen_Prostatico',
    'ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS': 'Antibiotico_Profilaxis',
    'NUMERO DE MUESTRAS TOMADAS': 'Numero_Muestras_Tomadas',
    'CUP': 'CUP',
    'ENF. CRONICA PULMONAR OBSTRUCTIVA': 'Enf_Cronica_Pulmonar_Obstructiva',
    'BIOPSIA': 'Biopsia',
    'NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA': 'Dias_Post_Biopsia_Complicacion',
    'FIEBRE': 'Fiebre',
    'ITU': 'ITU',
    'TIPO DE CULTIVO': 'Tipo_Cultivo',
    'AGENTE AISLADO': 'Agente_Aislado',
    'PATRON DE RESISTENCIA': 'Patron_Resistencia',
    'HOSPITALIZACION': 'Hospitalizacion',
    'DIAS HOSPITALIZACION MQ': 'Dias_Hospitalizacion_MQ',
    'DIAS HOSPITALIZACIÓN UPC': 'Dias_Hospitalizacion_UPC'
}
df = df.rename(columns=nuevos_nombres)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Edad                              568 non-null    float64
#  1   Diabetes                          568 non-null    object
#  2   Hospitalizacion_Ultimo_Mes        568 non-null    object
#  3   PSA                               564 non-null    object
#  4   Biopsias_Previas                  566 non-null    object
#  5   Volumen_Prostatico                567 non-null    object
#  6   Antibiotico_Profilaxis            568 non-null    object
#  7   Numero_Muestras_Tomadas           568 non-null    float64
#  8   CUP                               568 non-null    object
#  9   Enf_Cronica_Pulmonar_Obstructiva  566 non-null    object
#  10  Biopsia                           568 non-null    object
#  11  Dias_Post_Biopsia_Complicacion    568 non-null    object
#  12  Fiebre                            568 non-null    object
#  13  ITU                               568 non-null    object
#  14  Tipo_Cultivo                      568 non-null    object
#  15  Agente_Aislado                    551 non-null    object
#  16  Patron_Resistencia                568 non-null    object
#  17  Hospitalizacion                   565 non-null    object
#  18  Dias_Hospitalizacion_MQ           568 non-null    float64
#  19  Dias_Hospitalizacion_UPC          568 non-null    float64
# dtypes: float64(4), object(16)
# memory usage: 89.2+ KB

# %%
df.isnull().sum()
# Out:
# Edad                                 2
# Diabetes                             2
# Hospitalizacion_Ultimo_Mes           2
# PSA                                  6
# Biopsias_Previas                     4
# Volumen_Prostatico                   3
# Antibiotico_Profilaxis               2
# Numero_Muestras_Tomadas              2
# CUP                                  2
# Enf_Cronica_Pulmonar_Obstructiva     4
# Biopsia                              2
# Dias_Post_Biopsia_Complicacion       2
# Fiebre                               2
# ITU                                  2
# Tipo_Cultivo                         2
# Agente_Aislado                      19
# Patron_Resistencia                   2
# Hospitalizacion                      5
# Dias_Hospitalizacion_MQ              2
# Dias_Hospitalizacion_UPC             2
# dtype: int64

# %%
df.describe()
# Out:
#              Edad  Numero_Muestras_Tomadas  Dias_Hospitalizacion_MQ  \
# count  568.000000               568.000000               568.000000
# mean    63.882042                12.996479                 0.165493
# std      9.281517                 3.921180                 0.958066
# min     39.000000                 4.000000                 0.000000
# 25%     59.000000                12.000000                 0.000000
# 50%     64.000000                12.000000                 0.000000
# 75%     69.000000                12.000000                 0.000000
# max    151.000000                24.000000                12.000000
#
#        Dias_Hospitalizacion_UPC
# count                568.000000
# mean                   0.014085
# std                    0.196474
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.000000
# max                    3.000000
