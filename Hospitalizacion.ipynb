# %%
import pandas as pd

# %%
df = pd.read_csv('Hospitalización.csv', encoding='latin-1')

# %%
df
# Out:
#      EDAD DIABETES HOSPITALIZACIÃN ULTIMO MES   PSA BIOPSIAS PREVIAS  \
# 0    53.0       NO                          NO     4               NO
# 1    56.0       NO                          NO   7,7               NO
# 2    57.0       NO                          NO    29               SI
# 3    56.0       NO                          NO     7               NO
# 4    55.0       NO                          NO    29               SI
# ..    ...      ...                         ...   ...              ...
# 565  69.0       NO                          NO  4,43              NaN
# 566  67.0       NO                          NO     8               NO
# 567  59.0       NO                          NO     9               SI
# 568   NaN      NaN                         NaN   NaN              NaN
# 569   NaN      NaN                         NaN   NaN              NaN
#
#     VOLUMEN PROSTATICO ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS  \
# ...
